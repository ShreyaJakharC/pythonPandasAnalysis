# %% [markdown]
# # pandas exploration
# In this assignment you will select a data set and do some munging and analysis of it using `pandas`, Jupyter Notebooks, and associated Python-centric data science tools.

# %% [markdown]
# Import the core data science libraries:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Import the raw data
# In this section, you will import the raw data into a `pandas` DataFrame.

# %%
# place your code into this Code cell
df = pd.read_csv('data/readme.csv')

# %% [markdown]
# ## Data inspection
# In this section, you will show enough of your data for a viewer to get a general sense of how the data is structured and any unique features of it.  Complete each of the indicated tasks in a Code cell, making sure to include a Markdown cell above each Code cell that explains what is being shown by the code.
# - Show 5 rows, selected at random, from the data set.
# - Show each of the column names and their data types.
# - Show any unique features of your chosen data set.
#
# Feel free to add as many additional cells as you need to help explain the raw data.

# %%
# Shows the data in the data set.
df.head(5)
# Out:
#    CSD BOROUGH SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    1       M        M015  P.S. 015 Roberto Clemente     0K       GEN ED
# 1    1       M        M015  P.S. 015 Roberto Clemente     0K          CTT
# 2    1       M        M015  P.S. 015 Roberto Clemente     01       GEN ED
# 3    1       M        M015  P.S. 015 Roberto Clemente     01          CTT
# 4    1       M        M015  P.S. 015 Roberto Clemente     02       GEN ED
#
#   CORE SUBJECT (MS CORE and 9-12 ONLY) CORE COURSE (MS CORE and 9-12 ONLY)  \
# 0                                    -                                   -
# 1                                    -                                   -
# 2                                    -                                   -
# 3                                    -                                   -
# 4                                    -                                   -
#
#   SERVICE CATEGORY(K-9* ONLY)  NUMBER OF STUDENTS / SEATS FILLED  \
# ...

# %%
# shows 5 rows selected randomly from the data set.
df.sample(5)
# Out:
#        CSD BOROUGH SCHOOL CODE                      SCHOOL NAME GRADE   \
# 21483   25       Q        Q219            P.S. 219 Paul Klapper    NaN
# 26813   31       R        R080   The Michael J. Petrides School     01
# 12017   12       X        X690  Monroe Academy for Business/Law  09-12
# 26475   31       R        R049         I.S. 49 Berta A. Dreyfus     06
# 26980   31       R        R455          Tottenville High School  09-12
#
#       PROGRAM TYPE CORE SUBJECT (MS CORE and 9-12 ONLY)  \
# 21483          NaN                                  NaN
# 26813       GEN ED                                    -
# 12017      SPEC ED                              SCIENCE
# 26475          CTT                                    -
# 26980       GEN ED                              SCIENCE
#
#       CORE COURSE (MS CORE and 9-12 ONLY) SERVICE CATEGORY(K-9* ONLY)  \
# 21483                                 NaN                         NaN
# ...

# %%
# shows 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27611 entries, 0 to 27610
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   CSD                                   27611 non-null  int64
#  1   BOROUGH                               27611 non-null  object
#  2   SCHOOL CODE                           27611 non-null  object
#  3   SCHOOL NAME                           27611 non-null  object
#  4   GRADE                                 26127 non-null  object
#  5   PROGRAM TYPE                          26127 non-null  object
#  6   CORE SUBJECT (MS CORE and 9-12 ONLY)  26127 non-null  object
#  7   CORE COURSE (MS CORE and 9-12 ONLY)   26127 non-null  object
#  8   SERVICE CATEGORY(K-9* ONLY)           26127 non-null  object
#  9   NUMBER OF STUDENTS / SEATS FILLED     26127 non-null  float64
#  10  NUMBER OF SECTIONS                    26127 non-null  float64
# ...

# %% [markdown]
# The unique feautre of my data is that it has the highest and the lowest size of the class for each of the school.

# %% [markdown]
# ## Data munging
# Place your **data munging** code and documentation within this section.
# - Keep each of your Code cells short and focused on a single task.
# - Include a Markdown cell above each code cell that describes what task the code within the code cell is performing.
# - Make as many code cells as you need to complete the munging - a few have been created for you to start with.
# - Display 5 sample rows of the modified data after each transformation so a viewer can see how the data has changed.
#
# **Note**: If you believe that your data set does not require any munging, please explain in detail.  Create Markdown cells that explain your thinking and create Code cells that show any specific structures of the data you refer to in your explanation.

# %% [markdown]
# Step 1: I am deleting the columns that do not have the complete information(incomplete inforamtion submitted by the schools)

# %%
df1 = df.drop(["CSD","PROGRAM TYPE","CORE SUBJECT (MS CORE and 9-12 ONLY)","CORE COURSE (MS CORE and 9-12 ONLY)","SERVICE CATEGORY(K-9* ONLY)", "DATA SOURCE","SCHOOLWIDE PUPIL-TEACHER RATIO"], axis = 1)
df1.head(2)
# Out:
#   BOROUGH SCHOOL CODE                SCHOOL NAME GRADE   \
# 0       M        M015  P.S. 015 Roberto Clemente     0K
# 1       M        M015  P.S. 015 Roberto Clemente     0K
#
#    NUMBER OF STUDENTS / SEATS FILLED  NUMBER OF SECTIONS  AVERAGE CLASS SIZE  \
# 0                               19.0                 1.0                19.0
# 1                               21.0                 1.0                21.0
#
#    SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS
# 0                    19.0                   19.0
# 1                    21.0                   21.0

# %% [markdown]
# Step 2: Deleting the exisiting rows with missing inforamtion for better analysis.

# %%
df2 = df1.dropna()
df2.head(2)
# Out:
#   BOROUGH SCHOOL CODE                SCHOOL NAME GRADE   \
# 0       M        M015  P.S. 015 Roberto Clemente     0K
# 1       M        M015  P.S. 015 Roberto Clemente     0K
#
#    NUMBER OF STUDENTS / SEATS FILLED  NUMBER OF SECTIONS  AVERAGE CLASS SIZE  \
# 0                               19.0                 1.0                19.0
# 1                               21.0                 1.0                21.0
#
#    SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS
# 0                    19.0                   19.0
# 1                    21.0                   21.0

# %% [markdown]
# Step 3: Changing column name.

# %%
df3 = df2.rename(columns={'NUMBER OF STUDENTS / SEATS FILLED': 'NUMBER OF STUDENTS'})

# %% [markdown]
# Here is the final data after munging:

# %%
df3.head(2)
# Out:
#   BOROUGH SCHOOL CODE                SCHOOL NAME GRADE   NUMBER OF STUDENTS  \
# 0       M        M015  P.S. 015 Roberto Clemente     0K                19.0
# 1       M        M015  P.S. 015 Roberto Clemente     0K                21.0
#
#    NUMBER OF SECTIONS  AVERAGE CLASS SIZE  SIZE OF SMALLEST CLASS  \
# 0                 1.0                19.0                    19.0
# 1                 1.0                21.0                    21.0
#
#    SIZE OF LARGEST CLASS
# 0                   19.0
# 1                   21.0

# %% [markdown]
# ## Data analysis
# Place your **data analysis** code and documentation within this section.
# - Perform at least 5 different statistical or other analyses of different aspects of the data.
#     - Your analyses must be specific and relevant to your chosen data set and show interesting aspects of it.
#     - Include at least one analysis that includes grouping rows by a shared attribute and performing some kind of statistical analysis on each group.
#     - Sort the data in at least 1 of your analyses, but sort on its own does not constitute an analysis on its own.
# - Keep each of your Code cells short and focused on a single task.
# - Include a Markdown cell above each Code cell that describes what task the code within the Code cell is performing.
# - Make as many code cells as you need to complete the analysis - a few have been created for you to start with.

# %% [markdown]
# 1. The following will give us the sum of the students in each school. Here we include grouping rows by a shared attribute which is the same school name and performing mean on each group.

# %%
total_students_mean = df3.groupby('SCHOOL NAME')['NUMBER OF STUDENTS'].mean()
total_students_mean
# Out:
# SCHOOL NAME
# 47 The American Sign Language and English Secondary School     28.150000
# A. Philip Randolph Campus High School                         243.769231
# ACADEMY FOR HEALTH CAREERS                                     50.250000
# ACADEMY FOR PERSONAL LEADERSHIP AND EXCELLENCE                 46.625000
# ACORN Community High School                                    80.555556
#                                                                  ...
# Young Scholars' Academy for Discovery and Exploration          27.142857
# Young Women's Leadership School                                91.916667
# Young Women's Leadership School of Brooklyn                    58.062500
# Young Women's Leadership School, Astoria                       89.409091
# Young Women's Leadership School, Queens                        89.173913
# Name: NUMBER OF STUDENTS, Length: 1485, dtype: float64

# %%
# maximum_class_size_index = df3.groupby('SCHOOL NAME', 'GRADE')['SIZE OF LARGEST CLASS'].idxmax()
# max_1 = df.loc[maximum_class_size_index]
# maximum_class_size = max_1[['SCHOOL NAME', 'GRADE', 'SIZE OF LARGEST CLASS']]
# maximum_class_size
maximum_class_size = df3.groupby('SCHOOL NAME')['SIZE OF LARGEST CLASS'].max()
maximum_class_size
# Out:
# SCHOOL NAME
# 47 The American Sign Language and English Secondary School    24.0
# A. Philip Randolph Campus High School                         35.0
# ACADEMY FOR HEALTH CAREERS                                    23.0
# ACADEMY FOR PERSONAL LEADERSHIP AND EXCELLENCE                30.0
# ACORN Community High School                                   35.0
#                                                               ...
# Young Scholars' Academy for Discovery and Exploration         31.0
# Young Women's Leadership School                               34.0
# Young Women's Leadership School of Brooklyn                   22.0
# Young Women's Leadership School, Astoria                      25.0
# Young Women's Leadership School, Queens                       32.0
# Name: SIZE OF LARGEST CLASS, Length: 1485, dtype: float64

# %%
minimum_class_size = df3.groupby('SCHOOL NAME')['SIZE OF SMALLEST CLASS'].min().sort_values(ascending=False)
minimum_class_size
# Out:
# SCHOOL NAME
# BROOKLYN SCHOOL OF INQUIRY                        27.0
# EAGLE ACADEMY FOR YOUNG MEN III                   27.0
# Isaac Newton Middle School for Math & Science     27.0
# M.S. 250 West Side Collaborative Middle School    27.0
# The Anderson School                               26.0
#                                                   ...
# I.S. 228 David A. Boody                            2.0
# M.S. 053 Brian Piccolo                             2.0
# P.S./M.S. 029 Melrose School                       2.0
# P.S. 042 R. Vernam                                 2.0
# P.S. 179                                           2.0
# Name: SIZE OF SMALLEST CLASS, Length: 1485, dtype: float64

# %%
total_students_borough = df3.groupby('BOROUGH')['NUMBER OF STUDENTS'].sum()
total_students_borough
# Out:
# BOROUGH
# K    824707.0
# M    440311.0
# Q    755944.0
# R    172387.0
# X    579836.0
# Name: NUMBER OF STUDENTS, dtype: float64

# %%
maximum_class_size_borough = df3.groupby('BOROUGH')['SIZE OF LARGEST CLASS'].max()
maximum_class_size_borough
# Out:
# BOROUGH
# K    91.0
# M    95.0
# Q    75.0
# R    52.0
# X    96.0
# Name: SIZE OF LARGEST CLASS, dtype: float64

# %%
total_students_borough_describe = df3.groupby('BOROUGH')['NUMBER OF STUDENTS'].describe()
total_students_borough_describe
# Out:
#           count        mean         std  min   25%   50%    75%     max
# BOROUGH
# K        8069.0  102.206841  178.123929  3.0  25.0  53.0  103.0  2965.0
# M        4977.0   88.469158  129.590841  3.0  25.0  51.0   97.0  1944.0
# Q        5511.0  137.170024  238.834309  4.0  28.0  62.0  127.5  2813.0
# R        1146.0  150.424956  246.190117  5.0  29.0  66.0  129.0  2443.0
# X        6424.0   90.260897  124.390202  2.0  25.0  54.0  104.0  1807.0

# %%
maximum_section = df3.groupby('SCHOOL NAME')['NUMBER OF SECTIONS'].max().sort_values(ascending = True)
maximum_section
# Out:
# SCHOOL NAME
# P.S. 316 Elijah Stroud                        1.0
# P.S. 74 FUTURE LEADERS ELEMENTARY SCHOOL      1.0
# P.S. 770 New American Academy                 1.0
# P.S. 150                                      1.0
# P.S. 063 William McKinley                     1.0
#                                             ...
# New Dorp High School                         86.0
# Richmond Hill High School                    86.0
# John Bowne High School                       87.0
# John Adams High School                       97.0
# Brooklyn Technical High School              100.0
# Name: NUMBER OF SECTIONS, Length: 1485, dtype: float64

# %% [markdown]
# ## Data visualization
# In this section, you will create a few **visualizations** that show some of the insights you have gathered from this data.
# - Create at least 5 different visualizations, where each visualization shows different insights into the data.
# - Use at least 3 different visualization types (e.g. bar charts, line charts, stacked area charts, pie charts, etc)
# - Create a Markdown cell and a Code cell for each, where you explain and show the visualizations, respectively.
# - Create as many additional cells as you need to prepare the data for the visualizations.

# %%
total_students_mean = df3.groupby('SCHOOL NAME')['NUMBER OF STUDENTS'].mean()
total_students_mean.plot(kind='line', x='SCHOOL NAME', y='Mean', figsize=(10, 6))
plt.title('Mean of total students by School')
plt.xlabel('School Name')
plt.ylabel('Mean')
plt.show()
# The labels in x-axis are overlapping.

# %%
minimum_class_size = df3.groupby('SCHOOL NAME')['SIZE OF SMALLEST CLASS'].min()
maximum_class_size = df3.groupby('SCHOOL NAME')['SIZE OF LARGEST CLASS'].max()

maximum_class_size.plot(kind='line', x='SCHOOL NAME', y='SIZE OF LARGEST CLASS', label='Maximum Class Size', figsize=(10, 6))
minimum_class_size.plot(kind='line', x='SCHOOL NAME', y='SIZE OF SMALLEST CLASS', label='Minimum Class Size')

# Add a title, x-axis label, y-axis label, and legend
plt.title('Maximum and Minimum Class Size by School')
plt.xlabel('School Name')
plt.ylabel('Class Size')
plt.legend()

# %%
total_students_borough = df3.groupby('BOROUGH')['NUMBER OF STUDENTS'].sum()
plt.pie(total_students_borough, labels=total_students_borough.index, autopct='%1.1f%%', startangle=90)
plt.title('Total Number of Students by Borough')
plt.show()

# %%
maximum_class_size_borough = df3.groupby('BOROUGH')['SIZE OF LARGEST CLASS'].max()
maximum_class_size_borough.plot.bar()
plt.title('Maximum Class Size by Borough')
plt.xlabel('Borough')
plt.ylabel('Maximum Class Size')
plt.show()

# %%
maximum_section = df3.groupby('SCHOOL NAME')['NUMBER OF SECTIONS'].max()
maximum_section.plot(kind='line', x='SCHOOL NAME', y='Sections', figsize=(10, 6))
plt.title('Maximum sections by School')
plt.xlabel('School Name')
plt.ylabel('Section')
plt.show()
# The labels in x-axis are overlapping.
